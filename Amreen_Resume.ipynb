# %% [markdown]
# # <center><u> RESUME </u></center>
#  ![](data:image/jpg;base64,...)
#  <b> Name <b> :  Amreen Shaikh
#
#  <b>Email- id<b> : `amreenars777@gmail.com`
#
# <b>Cell-No<b>   : `7875727569`
#
# <b>linkedin peofile<b>:- ! [linked in](https://www.linkedin.com/in/amreen-shaikh-5571191a0/)
#
# ## <u> Career objective: <u>
#
#    i am a data science professional with experience in data analysis,machine learning,and predictive modelling i am passionate about data and its potential to impact leverage my skils in data science to help organization achieve their goals
#
# ## <u> Educational details: </u>
#
#  * M.tech -  Data science 2021-23
#     * Savitribai phule University Pune
#  * B.tech -Data science  2017-21
#     * Dr.D.Y.Patil technology college pune
#  * HSC- 2016-17
#     * Dayanand Science College latur
#  * SSC-2015-16
#     * <c>kamla nehru high school<c>
#
#
# ## <u>Technical Skills:<u>
#
# * proramming languages:
#    * Python, R, SQL
#
# * Deep learning
# * machine learning
#
# * Data visualisation:
#    * Tablue,NUmpy,Pandas
#
# ## <u> Certifications <u>:
#
# ###### online course in stastics with R (Duke University)
# -Introduction to Probablity and Data,Inferenial Stastistic,linear Regression and Modelling
#
# ###### Machine Learning Specialization-online(coursera)
# -Machine Learning Foundations,Regression,Classification
#
# ###### Online Course in data Science Specialization
# -Data scientist toolbox,R progeamming,Getting and Cleaning Data Exploiratory Analysis,Reproducible research,Stastical Interferance,Regression Models,
#
# ## <u> Project: </u>
#
# ##### sentiment analysis of Product Review :
# In this Project I collect a dataset of Product reviews from an flipkart.The goal would be to perform sentiment analysis to determine whether a review is positive,negative, or neutral.Preprocesses the text data, tokenize and clean it,and train a machinne learning model to classify the sentiment of each review accurately. Text data preproessing,feature extraction from text,and classification techniques
#
# ##### Image classification for disease detection:
# image classification model to identify diseases or conditions from medical images such as X ray or MRIs collect a labeled dataset containing images of healthy and affected cases.Preprocess the images,augument the data ,and use  deep learning techniques like convolutional neural networks to build a model that can accurately classify the images
#
# ## Intership:
# Data Analysis Assistant 2023
# innomatics research lab
# Used R to parallelize preexisting code to make data analysis processes faster.
# Researched, created, and maintained public company management profiles and individual executive and director biographical profiles for equity database.
# ## <u> soft skill <u>:
# * Attention to Detail and Accuracy
# * Communication and Interpersonal Skills
# * Creativity and Innovation
# * Critical Thinking and Decision Making
# * Data Visualization and Presentation Skills
# * Flexibility and Adaptability
# * Learning Agility and Curiosity
# * Project Management and Time Management
# * Teamwork and Collaboration
# * Technical Writing and Documentation
# * Work Ethic and Professionalism
# ## <u>language <u>:
# Hindi,English ,Marathi
# ## <u> self declration <u>:
# I here by declare that all the information provided by me is true
